# %% [markdown]
# This code uses factorial design of recursion

# %%
def PrintPython100Times(a):
    if a == 1:
        return 1
        
    else:
        print(f"Python{a}")
        PrintPython100Times(a-1)
        

PrintPython100Times(101)
# Out:
# Python101
# Python100
# Python99
# Python98
# Python97
# Python96
# Python95
# Python94
# Python93
# Python92
# Python91
# Python90
# Python89
# Python88
# Python87
# Python86
# Python85
# Python84
# Python83
# Python82
# Python81
# Python80
# Python79
# Python78
# Python77
# Python76
# Python75
# Python74
# Python73
# Python72
# Python71
# Python70
# Python69
# Python68
# Python67
# Python66
# Python65
# Python64
# Python63
# Python62
# Python61
# Python60
# Python59
# Python58
# Python57
# Python56
# Python55
# Python54
# Python53
# Python52
# Python51
# Python50
# Python49
# Python48
# Python47
# Python46
# Python45
# Python44
# Python43
# Python42
# Python41
# Python40
# Python39
# Python38
# Python37
# Python36
# Python35
# Python34
# Python33
# Python32
# Python31
# Python30
# Python29
# Python28
# Python27
# Python26
# Python25
# Python24
# Python23
# Python22
# Python21
# Python20
# Python19
# Python18
# Python17
# Python16
# Python15
# Python14
# Python13
# Python12
# ...
