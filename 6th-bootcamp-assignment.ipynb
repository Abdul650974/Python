# %% [markdown]
# # Capstone Project

# %% [markdown]
# ### Do The following :
# - Finish the practice
# - share it on your github account
# - notify me at m.kutbi@seu.edu.sa if you faced any difficulties or when you finish

# %% [markdown]
# Search for a dataset you like in UCI Machine learning Repository https://archive.ics.uci.edu/ml/index.php
# Download the data and move it into your current directory (where your python is running now)

# %% [markdown]
# First step: Load data into numpy, pandas or both

# %%
import numpy as np
import pandas as pd
filename = './dataset-6.txt'
dataset = np.loadtxt(filename, delimiter = ",")
print(dataset.shape)
print(dataset)

#Another way to load dataset-6.txt
#import csv

#list = []
#input = open('dataset-6.txt', 'rt')
#reader = csv.reader(input)
#for line in reader:
#    list.append(line)
    #print (line)
#    print(list)
# Out:
# (189, 23)
# [[  1.   1. 600. ...   0.   0.   0.]
#  [  2.   1. 700. ...   0.   1.   0.]
#  [  3.   1. 200. ...   0.   1.   0.]
#  ...
#  [187.  52. 500. ...   0.   1.   0.]
#  [188.  52. 300. ...   0.   0.   0.]
#  [189.  52. 300. ...   0.   0.   0.]]

# %% [markdown]
# #### print head and tail of data

# %%
#df = pd.DataFrame(dataset, index=[:], columns=[:])
dataset.head(8)
#list2 = dataset.tolist()
#list2.head()
# Out:
#   File "<ipython-input-30-e026b3c8c762>", line 1
#     df = pd.DataFrame(dataset, index=[:], columns=[:])
#                                       ^
# SyntaxError: invalid syntax

# %% [markdown]
# #### Clean the data if needed

# %%
## TODO

# %% [markdown]
# #### import the package Matlibplot, Sklean

# %%
import matplotlib.pyplot as plt
# %matplotlib inline
import numpy as np
import math

plt.hist(dataset, 1)
plt.show()

# %% [markdown]
# #### Visulaize the data in different types of figures as you see fit

# %%
from mpl_toolkits import mplot3d
import numpy as np
import matplotlib.pyplot as plt
fig = plt.figure()
ax = plt.axes(projection='3d')
z = np.linspace(0,1,100)
x =  dataset
y =  dataset
ax.plot3D(x,y,z, 'blue')
ax.set_title('3D line plot')
#plt.tight_layout()
plt.show()
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-18-e8d7dc2c6b59> in <module>
#       7 x =  dataset
#       8 y =  dataset
# ----> 9 ax.plot3D(x,y,z, 'blue')
#      10 ax.set_title('3D line plot')
#      11 #plt.tight_layout()
#
# ~\anaconda3\lib\site-packages\mpl_toolkits\mplot3d\axes3d.py in plot(self, xs, ys, zdir, *args, **kwargs)
#    1467
#    1468         # Match length
# -> 1469         zs = np.broadcast_to(zs, np.shape(xs))
#    1470
#    1471         lines = super().plot(xs, ys, *args, **kwargs)
#
# <__array_function__ internals> in broadcast_to(*args, **kwargs)
#
# ~\anaconda3\lib\site-packages\numpy\lib\stride_tricks.py in broadcast_to(array, shape, subok)
#     178            [1, 2, 3]])
#     179     """
# --> 180     return _broadcast_to(array, shape, subok=subok, readonly=True)
#     181
#     182
#
# ~\anaconda3\lib\site-packages\numpy\lib\stride_tricks.py in _broadcast_to(array, shape, subok, readonly)
#     121                          'negative')
#     122     extras = []
# --> 123     it = np.nditer(
#     124         (array,), flags=['multi_index', 'refs_ok', 'zerosize_ok'] + extras,
#     125         op_flags=['readonly'], itershape=shape, order='C')
#
# ValueError: operands could not be broadcast together with remapped shapes [original->remapped]: (100,) and requested shape (189,23)

# %%
value1 = np.random.normal(20, 30, 300)
value2 = np.random.normal(50, 15, 300)
data_range = np.arange(0,300,1)
fig=plt.figure()
ax=fig.add_axes([0,0,1,1])
ax.scatter(data_range, value1, color='red')
ax.scatter(data_range, value2, color='g')
ax.set_xlabel('Data Range')
ax.set_ylabel('Data Set')
ax.set_title('Amphibians')
plt.show()

# %% [markdown]
# #### Be creative!! and use clustering or classification methods on the data

# %%
DBSCAN
KMeans
